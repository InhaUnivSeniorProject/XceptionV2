# %% [markdown]
# <a href="https://colab.research.google.com/github/simjeongho/XceptionV2/blob/main/File_Delete_Rename.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import functools
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import tqdm
import time
from IPython import display
from tensorflow import keras 
from tensorflow.keras.layers import *
from pathlib import Path

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = Path('/content/drive/MyDrive/generate_1/')
path2 = Path('/content/drive/MyDrive/generate_2/')
path3 = Path('/content/drive/MyDrive/generate_33/')
pathString ='/content/drive/MyDrive/generate_1/'
pathString2 ='/content/drive/MyDrive/generate_2/'
pathString3 ='/content/drive/MyDrive/generate_33/'
len(os.listdir(path3))
# Out:
# 1931

# %%
import os
import glob
from shutil import copyfile
from tqdm import tqdm
import fnmatch

# %%
[os.remove(f) for f in glob.glob("/content/drive/MyDrive/generate_1/*_복사본.jpg")]
# Out:
# []

# %%
def remove_file(path):
  files=glob.glob(path);
  
  file_list_copy = [file for file in files if file.endswith("복사본.jpg")]

  for json in tqdm(file_list_copy):
    print("Delete : %s"%json)
    os.remove(json)

# %%
for fname in os.listdir(path):
  if fname.startswith('*'):
    print(fname)

# %%
for filename in os.listdir(path):
  if fnmatch.fnmatch(filename, '*-*.jpg'):
    os.remove(pathString+filename)
    print(filename)
# Out:
# 7936 - 복사본.jpg
# 8196 - 복사본.jpg
# 8463 - 복사본.jpg
# 7939 - 복사본.jpg
# 7434 - 복사본.jpg
# 8971 - 복사본.jpg
# 7174 - 복사본.jpg
# 7425 - 복사본.jpg
# 6923 - 복사본.jpg
# 8197 - 복사본.jpg
# 7169 - 복사본.jpg
# 7428 - 복사본.jpg
# 8460 - 복사본.jpg
# 7168 - 복사본.jpg
# 7692 - 복사본.jpg
# 6922 - 복사본.jpg
# 7426 - 복사본.jpg
# 7424 - 복사본.jpg
# 9229 - 복사본.jpg
# 7175 - 복사본.jpg
# 7937 - 복사본.jpg
# 7436 - 복사본.jpg
# 7176 - 복사본.jpg
# 7183 - 복사본.jpg
# 7182 - 복사본.jpg
# 7172 - 복사본.jpg
# 9730 - 복사본.jpg
# 6926 - 복사본.jpg
# 7177 - 복사본.jpg
# 6915 - 복사본.jpg
# 7170 - 복사본.jpg
# 7430 - 복사본.jpg
# 7689 - 복사본.jpg
# 7432 - 복사본.jpg
# 6920 - 복사본.jpg
# 7181 - 복사본.jpg
# 7680 - 복사본.jpg
# 7437 - 복사본.jpg
# 6927 - 복사본.jpg
# 7180 - 복사본.jpg
# 7179 - 복사본.jpg
# 7171 - 복사본.jpg
# 7429 - 복사본.jpg
# 7435 - 복사본.jpg
# 7178 - 복사본.jpg
# ...

# %%
i = 1
for filename in os.listdir(path):
    os.rename(pathString+filename, pathString+'myLi1_'+str(i)+'.jpg')
    print(filename)
    i+=1
# Out:
# myLi11.jpg
# myLi12.jpg
# myLi13.jpg
# myLi14.jpg
# myLi15.jpg
# myLi16.jpg
# myLi17.jpg
# myLi18.jpg
# myLi19.jpg
# myLi110.jpg
# myLi111.jpg
# myLi112.jpg
# myLi113.jpg
# myLi114.jpg
# myLi115.jpg
# myLi116.jpg
# myLi117.jpg
# myLi118.jpg
# myLi119.jpg
# myLi120.jpg
# myLi121.jpg
# myLi122.jpg
# myLi123.jpg
# myLi124.jpg
# myLi125.jpg
# myLi126.jpg
# myLi127.jpg
# myLi128.jpg
# myLi129.jpg
# myLi130.jpg
# myLi131.jpg
# myLi132.jpg
# myLi133.jpg
# myLi134.jpg
# myLi135.jpg
# myLi136.jpg
# myLi137.jpg
# myLi138.jpg
# myLi139.jpg
# myLi140.jpg
# myLi141.jpg
# myLi142.jpg
# myLi143.jpg
# myLi144.jpg
# myLi145.jpg
# myLi146.jpg
# myLi147.jpg
# myLi148.jpg
# myLi149.jpg
# myLi150.jpg
# myLi151.jpg
# myLi152.jpg
# myLi153.jpg
# myLi154.jpg
# myLi155.jpg
# myLi156.jpg
