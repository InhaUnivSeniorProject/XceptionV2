# %% [markdown]
# <a href="https://colab.research.google.com/github/simjeongho/XceptionV2/blob/main/XceptionKeras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
import warnings

# %%
#import necessary libraries

import tensorflow as tf
from tensorflow.keras.layers import Input,Dense,Conv2D,Add
from tensorflow.keras.layers import SeparableConv2D,ReLU
from tensorflow.keras.layers import BatchNormalization,MaxPool2D
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam , RMSprop 
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint , LearningRateScheduler

# %%
#convolution 연산을 수행하는 함수 BatchNormalization 까지 수행한다. 

def conv_bn(x, filters, kernel_size, strides=1):
    
    x = Conv2D(filters=filters, 
               kernel_size = kernel_size, 
               strides=strides, 
               padding = 'same', 
               use_bias = False)(x)
    x = BatchNormalization()(x)
    return x

# %%
#Separable Convolution을 수행하는 함수에 해당한다. 

def sep_bn(x, filters, kernel_size, strides=1):
    
    x = SeparableConv2D(filters=filters, 
                        kernel_size = kernel_size, 
                        strides=strides, 
                        padding = 'same', 
                        use_bias = False)(x)
    x = BatchNormalization()(x)
    return x

# %%
#entry Flow ReLu()함수는 따로 수행해주었다. 


def entry_flow(x):
    
    x = conv_bn(x, filters =32, kernel_size =3, strides=2)
    x = ReLU()(x)
    x = conv_bn(x, filters =64, kernel_size =3, strides=1)
    tensor = ReLU()(x)
    
    x = sep_bn(tensor, filters = 128, kernel_size =3)
    x = ReLU()(x)
    x = sep_bn(x, filters = 128, kernel_size =3)
    x = MaxPool2D(pool_size=3, strides=2, padding = 'same')(x)
    
    tensor = conv_bn(tensor, filters=128, kernel_size = 1,strides=2)
    x = Add()([tensor,x])
    
    x = ReLU()(x)
    x = sep_bn(x, filters =256, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters =256, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding = 'same')(x)
    
    tensor = conv_bn(tensor, filters=256, kernel_size = 1,strides=2)
    x = Add()([tensor,x])
    
    x = ReLU()(x)
    x = sep_bn(x, filters =728, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters =728, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding = 'same')(x)
    
    tensor = conv_bn(tensor, filters=728, kernel_size = 1,strides=2)
    x = Add()([tensor,x])
    return x

# %%
# middle flow

def middle_flow(tensor):
    
    for _ in range(8):
        x = ReLU()(tensor)
        x = sep_bn(x, filters = 728, kernel_size = 3)
        x = ReLU()(x)
        x = sep_bn(x, filters = 728, kernel_size = 3)
        x = ReLU()(x)
        x = sep_bn(x, filters = 728, kernel_size = 3)
        x = ReLU()(x)
        tensor = Add()([tensor,x])
        
    return tensor

# %%
# exit flow

def exit_flow(tensor, n_classes):
    
    x = ReLU()(tensor)
    x = sep_bn(x, filters = 728,  kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters = 1024,  kernel_size=3)
    x = MaxPool2D(pool_size = 3, strides = 2, padding ='same')(x)
    
    tensor = conv_bn(tensor, filters =1024, kernel_size=1, strides =2)
    x = Add()([tensor,x])
    
    x = sep_bn(x, filters = 1536,  kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters = 2048,  kernel_size=3)
    x = GlobalAveragePooling2D()(x)
    
    x = Dense (n_classes, activation = 'softmax')(x)
    
    return x

# %%
def create_Xception(in_shape=(224,224,3), n_classes=10):
  input_tensor = Input(shape=in_shape)
  x = entry_flow(input_tensor)
  x = middle_flow(x)
  output = exit_flow(x, n_classes)

  model = Model(inputs=input_tensor, outputs=output)

  return model

# %%
xception = create_Xception(in_shape=(224,224,3), n_classes=10)

xception.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_54 (Conv2D)             (None, 112, 112, 32  864         ['input_10[0][0]']
#                                 )
#
#  batch_normalization_360 (Batch  (None, 112, 112, 32  128        ['conv2d_54[0][0]']
#  Normalization)                 )
#
#  re_lu_378 (ReLU)               (None, 112, 112, 32  0           ['batch_normalization_360[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 112, 112, 64  18432       ['re_lu_378[0][0]']
#                                 )
#
#  batch_normalization_361 (Batch  (None, 112, 112, 64  256        ['conv2d_55[0][0]']
#  Normalization)                 )
#
#  re_lu_379 (ReLU)               (None, 112, 112, 64  0           ['batch_normalization_361[0][0]']
#                                 )
#
#  separable_conv2d_306 (Separabl  (None, 112, 112, 12  8768       ['re_lu_379[0][0]']
#  eConv2D)                       8)
#
#  batch_normalization_362 (Batch  (None, 112, 112, 12  512        ['separable_conv2d_306[0][0]']
#  Normalization)                 8)
#
#  re_lu_380 (ReLU)               (None, 112, 112, 12  0           ['batch_normalization_362[0][0]']
#                                 8)
#
#  separable_conv2d_307 (Separabl  (None, 112, 112, 12  17536      ['re_lu_380[0][0]']
#  eConv2D)                       8)
#
#  conv2d_56 (Conv2D)             (None, 56, 56, 128)  8192        ['re_lu_379[0][0]']
#
#  batch_normalization_363 (Batch  (None, 112, 112, 12  512        ['separable_conv2d_307[0][0]']
#  Normalization)                 8)
#
#  batch_normalization_364 (Batch  (None, 56, 56, 128)  512        ['conv2d_56[0][0]']
#  Normalization)
#
#  max_pooling2d_36 (MaxPooling2D  (None, 56, 56, 128)  0          ['batch_normalization_363[0][0]']
#  )
#
#  add_108 (Add)                  (None, 56, 56, 128)  0           ['batch_normalization_364[0][0]',
#                                                                   'max_pooling2d_36[0][0]']
#
#  re_lu_381 (ReLU)               (None, 56, 56, 128)  0           ['add_108[0][0]']
#
#  separable_conv2d_308 (Separabl  (None, 56, 56, 256)  33920      ['re_lu_381[0][0]']
#  eConv2D)
#
#  batch_normalization_365 (Batch  (None, 56, 56, 256)  1024       ['separable_conv2d_308[0][0]']
#  Normalization)
#
#  re_lu_382 (ReLU)               (None, 56, 56, 256)  0           ['batch_normalization_365[0][0]']
#
#  separable_conv2d_309 (Separabl  (None, 56, 56, 256)  67840      ['re_lu_382[0][0]']
#  eConv2D)
#
#  conv2d_57 (Conv2D)             (None, 28, 28, 256)  32768       ['batch_normalization_364[0][0]']
#
#  batch_normalization_366 (Batch  (None, 56, 56, 256)  1024       ['separable_conv2d_309[0][0]']
#  Normalization)
#
#  batch_normalization_367 (Batch  (None, 28, 28, 256)  1024       ['conv2d_57[0][0]']
#  Normalization)
#
#  max_pooling2d_37 (MaxPooling2D  (None, 28, 28, 256)  0          ['batch_normalization_366[0][0]']
#  )
#
#  add_109 (Add)                  (None, 28, 28, 256)  0           ['batch_normalization_367[0][0]',
#                                                                   'max_pooling2d_37[0][0]']
#
#  re_lu_383 (ReLU)               (None, 28, 28, 256)  0           ['add_109[0][0]']
#
#  separable_conv2d_310 (Separabl  (None, 28, 28, 728)  188672     ['re_lu_383[0][0]']
#  eConv2D)
#
#  batch_normalization_368 (Batch  (None, 28, 28, 728)  2912       ['separable_conv2d_310[0][0]']
#  Normalization)
#
#  re_lu_384 (ReLU)               (None, 28, 28, 728)  0           ['batch_normalization_368[0][0]']
#
#  separable_conv2d_311 (Separabl  (None, 28, 28, 728)  536536     ['re_lu_384[0][0]']
#  eConv2D)
#
#  conv2d_58 (Conv2D)             (None, 14, 14, 728)  186368      ['batch_normalization_367[0][0]']
#
#  batch_normalization_369 (Batch  (None, 28, 28, 728)  2912       ['separable_conv2d_311[0][0]']
#  Normalization)
#
#  batch_normalization_370 (Batch  (None, 14, 14, 728)  2912       ['conv2d_58[0][0]']
#  Normalization)
#
#  max_pooling2d_38 (MaxPooling2D  (None, 14, 14, 728)  0          ['batch_normalization_369[0][0]']
#  )
#
#  add_110 (Add)                  (None, 14, 14, 728)  0           ['batch_normalization_370[0][0]',
#                                                                   'max_pooling2d_38[0][0]']
#
#  re_lu_385 (ReLU)               (None, 14, 14, 728)  0           ['add_110[0][0]']
#
#  separable_conv2d_312 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_385[0][0]']
#  eConv2D)
#
#  batch_normalization_371 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_312[0][0]']
#  Normalization)
#
#  re_lu_386 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_371[0][0]']
#
#  separable_conv2d_313 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_386[0][0]']
#  eConv2D)
#
#  batch_normalization_372 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_313[0][0]']
#  Normalization)
#
#  re_lu_387 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_372[0][0]']
#
#  separable_conv2d_314 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_387[0][0]']
#  eConv2D)
#
#  batch_normalization_373 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_314[0][0]']
#  Normalization)
#
#  re_lu_388 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_373[0][0]']
#
#  add_111 (Add)                  (None, 14, 14, 728)  0           ['add_110[0][0]',
#                                                                   're_lu_388[0][0]']
#
#  re_lu_389 (ReLU)               (None, 14, 14, 728)  0           ['add_111[0][0]']
#
#  separable_conv2d_315 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_389[0][0]']
#  eConv2D)
#
#  batch_normalization_374 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_315[0][0]']
#  Normalization)
#
#  re_lu_390 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_374[0][0]']
#
#  separable_conv2d_316 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_390[0][0]']
#  eConv2D)
#
#  batch_normalization_375 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_316[0][0]']
#  Normalization)
#
#  re_lu_391 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_375[0][0]']
#
#  separable_conv2d_317 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_391[0][0]']
#  eConv2D)
#
#  batch_normalization_376 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_317[0][0]']
#  Normalization)
#
#  re_lu_392 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_376[0][0]']
#
#  add_112 (Add)                  (None, 14, 14, 728)  0           ['add_111[0][0]',
#                                                                   're_lu_392[0][0]']
#
#  re_lu_393 (ReLU)               (None, 14, 14, 728)  0           ['add_112[0][0]']
#
#  separable_conv2d_318 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_393[0][0]']
#  eConv2D)
#
#  batch_normalization_377 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_318[0][0]']
#  Normalization)
#
#  re_lu_394 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_377[0][0]']
#
#  separable_conv2d_319 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_394[0][0]']
#  eConv2D)
#
#  batch_normalization_378 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_319[0][0]']
#  Normalization)
#
#  re_lu_395 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_378[0][0]']
#
#  separable_conv2d_320 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_395[0][0]']
#  eConv2D)
#
#  batch_normalization_379 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_320[0][0]']
#  Normalization)
#
#  re_lu_396 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_379[0][0]']
#
#  add_113 (Add)                  (None, 14, 14, 728)  0           ['add_112[0][0]',
#                                                                   're_lu_396[0][0]']
#
#  re_lu_397 (ReLU)               (None, 14, 14, 728)  0           ['add_113[0][0]']
#
#  separable_conv2d_321 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_397[0][0]']
#  eConv2D)
#
#  batch_normalization_380 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_321[0][0]']
#  Normalization)
#
#  re_lu_398 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_380[0][0]']
#
#  separable_conv2d_322 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_398[0][0]']
#  eConv2D)
#
#  batch_normalization_381 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_322[0][0]']
#  Normalization)
#
#  re_lu_399 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_381[0][0]']
#
#  separable_conv2d_323 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_399[0][0]']
#  eConv2D)
#
#  batch_normalization_382 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_323[0][0]']
#  Normalization)
#
#  re_lu_400 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_382[0][0]']
#
#  add_114 (Add)                  (None, 14, 14, 728)  0           ['add_113[0][0]',
#                                                                   're_lu_400[0][0]']
#
#  re_lu_401 (ReLU)               (None, 14, 14, 728)  0           ['add_114[0][0]']
#
#  separable_conv2d_324 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_401[0][0]']
#  eConv2D)
#
#  batch_normalization_383 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_324[0][0]']
#  Normalization)
#
#  re_lu_402 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_383[0][0]']
#
#  separable_conv2d_325 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_402[0][0]']
#  eConv2D)
#
#  batch_normalization_384 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_325[0][0]']
#  Normalization)
#
#  re_lu_403 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_384[0][0]']
#
#  separable_conv2d_326 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_403[0][0]']
#  eConv2D)
#
#  batch_normalization_385 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_326[0][0]']
#  Normalization)
#
#  re_lu_404 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_385[0][0]']
#
#  add_115 (Add)                  (None, 14, 14, 728)  0           ['add_114[0][0]',
#                                                                   're_lu_404[0][0]']
#
#  re_lu_405 (ReLU)               (None, 14, 14, 728)  0           ['add_115[0][0]']
#
#  separable_conv2d_327 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_405[0][0]']
#  eConv2D)
#
#  batch_normalization_386 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_327[0][0]']
#  Normalization)
#
#  re_lu_406 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_386[0][0]']
#
#  separable_conv2d_328 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_406[0][0]']
#  eConv2D)
#
#  batch_normalization_387 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_328[0][0]']
#  Normalization)
#
#  re_lu_407 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_387[0][0]']
#
#  separable_conv2d_329 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_407[0][0]']
#  eConv2D)
#
#  batch_normalization_388 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_329[0][0]']
#  Normalization)
#
#  re_lu_408 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_388[0][0]']
#
#  add_116 (Add)                  (None, 14, 14, 728)  0           ['add_115[0][0]',
#                                                                   're_lu_408[0][0]']
#
#  re_lu_409 (ReLU)               (None, 14, 14, 728)  0           ['add_116[0][0]']
#
#  separable_conv2d_330 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_409[0][0]']
#  eConv2D)
#
#  batch_normalization_389 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_330[0][0]']
#  Normalization)
#
#  re_lu_410 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_389[0][0]']
#
#  separable_conv2d_331 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_410[0][0]']
#  eConv2D)
#
#  batch_normalization_390 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_331[0][0]']
#  Normalization)
#
#  re_lu_411 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_390[0][0]']
#
#  separable_conv2d_332 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_411[0][0]']
#  eConv2D)
#
#  batch_normalization_391 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_332[0][0]']
#  Normalization)
#
#  re_lu_412 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_391[0][0]']
#
#  add_117 (Add)                  (None, 14, 14, 728)  0           ['add_116[0][0]',
#                                                                   're_lu_412[0][0]']
#
#  re_lu_413 (ReLU)               (None, 14, 14, 728)  0           ['add_117[0][0]']
#
#  separable_conv2d_333 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_413[0][0]']
#  eConv2D)
#
#  batch_normalization_392 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_333[0][0]']
#  Normalization)
#
#  re_lu_414 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_392[0][0]']
#
#  separable_conv2d_334 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_414[0][0]']
#  eConv2D)
#
#  batch_normalization_393 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_334[0][0]']
#  Normalization)
#
#  re_lu_415 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_393[0][0]']
#
#  separable_conv2d_335 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_415[0][0]']
#  eConv2D)
#
#  batch_normalization_394 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_335[0][0]']
#  Normalization)
#
#  re_lu_416 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_394[0][0]']
#
#  add_118 (Add)                  (None, 14, 14, 728)  0           ['add_117[0][0]',
#                                                                   're_lu_416[0][0]']
#
#  re_lu_417 (ReLU)               (None, 14, 14, 728)  0           ['add_118[0][0]']
#
#  separable_conv2d_336 (Separabl  (None, 14, 14, 728)  536536     ['re_lu_417[0][0]']
#  eConv2D)
#
#  batch_normalization_395 (Batch  (None, 14, 14, 728)  2912       ['separable_conv2d_336[0][0]']
#  Normalization)
#
#  re_lu_418 (ReLU)               (None, 14, 14, 728)  0           ['batch_normalization_395[0][0]']
#
#  separable_conv2d_337 (Separabl  (None, 14, 14, 1024  752024     ['re_lu_418[0][0]']
#  eConv2D)                       )
#
#  conv2d_59 (Conv2D)             (None, 7, 7, 1024)   745472      ['add_118[0][0]']
#
#  batch_normalization_396 (Batch  (None, 14, 14, 1024  4096       ['separable_conv2d_337[0][0]']
#  Normalization)                 )
#
#  batch_normalization_397 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_59[0][0]']
#  Normalization)
#
#  max_pooling2d_39 (MaxPooling2D  (None, 7, 7, 1024)  0           ['batch_normalization_396[0][0]']
#  )
#
#  add_119 (Add)                  (None, 7, 7, 1024)   0           ['batch_normalization_397[0][0]',
#                                                                   'max_pooling2d_39[0][0]']
#
#  separable_conv2d_338 (Separabl  (None, 7, 7, 1536)  1582080     ['add_119[0][0]']
#  eConv2D)
#
#  batch_normalization_398 (Batch  (None, 7, 7, 1536)  6144        ['separable_conv2d_338[0][0]']
#  Normalization)
#
#  re_lu_419 (ReLU)               (None, 7, 7, 1536)   0           ['batch_normalization_398[0][0]']
#
#  separable_conv2d_339 (Separabl  (None, 7, 7, 2048)  3159552     ['re_lu_419[0][0]']
#  eConv2D)
#
#  batch_normalization_399 (Batch  (None, 7, 7, 2048)  8192        ['separable_conv2d_339[0][0]']
#  Normalization)
#
#  global_average_pooling2d_8 (Gl  (None, 2048)        0           ['batch_normalization_399[0][0]']
#  obalAveragePooling2D)
#
#  dense_8 (Dense)                (None, 10)           20490       ['global_average_pooling2d_8[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 20,881,970
# Trainable params: 20,827,442
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %% [markdown]
# # 데이터 셋 불러오기

# %%
IMAGE_SIZE = 128
BATCH_SIZE = 64

# %%
import random as python_random
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import Sequence
import cv2
import sklearn

# 픽셀 값 계산 
def zero_one_scaler(image):
    return image/255.0

def get_preprocessed_ohe(images, labels, pre_func=None):
    # preprocessing 함수가 입력되면 이를 이용하여 image array를 scaling 적용.
    if pre_func is not None:
        images = pre_func(images)
    # OHE 적용    
    oh_labels = to_categorical(labels)
    return images, oh_labels

# 학습/검증/테스트 데이터 세트에 전처리 및 OHE 적용한 뒤 반환 
def get_train_valid_test_set(train_images, train_labels, test_images, test_labels, valid_size=0.15, random_state=2021):
    # 학습 및 테스트 데이터 세트를  0 ~ 1사이값 float32로 변경 및 OHE 적용. 
    train_images, train_oh_labels = get_preprocessed_ohe(train_images, train_labels)
    test_images, test_oh_labels = get_preprocessed_ohe(test_images, test_labels)
    
    # 학습 데이터를 검증 데이터 세트로 다시 분리
    tr_images, val_images, tr_oh_labels, val_oh_labels = train_test_split(train_images, train_oh_labels, test_size=valid_size, random_state=random_state)
    
    return (tr_images, tr_oh_labels), (val_images, val_oh_labels), (test_images, test_oh_labels )

from tensorflow.keras.utils import Sequence
import cv2
import sklearn

# 입력 인자 images_array labels는 모두 numpy array로 들어옴. 
# 인자로 입력되는 images_array는 전체 32x32 image array임. 
class CIFAR_Dataset(Sequence):
    def __init__(self, images_array, labels, batch_size=BATCH_SIZE, augmentor=None, shuffle=False, pre_func=None):
        '''
        파라미터 설명
        images_array: 원본 32x32 만큼의 image 배열값 - cifar10은 32x32이기 때문에 . 
        labels: 해당 image의 label들
        batch_size: __getitem__(self, index) 호출 시 마다 가져올 데이터 batch 건수
        augmentor: albumentations 객체
        shuffle: 학습 데이터의 경우 epoch 종료시마다 데이터를 섞을지 여부
        '''
        # 객체 생성 인자로 들어온 값을 객체 내부 변수로 할당. 
        # 인자로 입력되는 images_array는 전체 32x32 image array임.
        self.images_array = images_array
        self.labels = labels
        self.batch_size = batch_size
        self.augmentor = augmentor
        self.pre_func = pre_func
        # train data의 경우 
        self.shuffle = shuffle
        if self.shuffle:
            # 객체 생성시에 한번 데이터를 섞음. 
            #self.on_epoch_end()
            pass
    
    # Sequence를 상속받은 Dataset은 batch_size 단위로 입력된 데이터를 처리함. 
    # __len__()은 전체 데이터 건수가 주어졌을 때 batch_size단위로 몇번 데이터를 반환하는지 나타남
    def __len__(self):
        # batch_size단위로 데이터를 몇번 가져와야하는지 계산하기 위해 전체 데이터 건수를 batch_size로 나누되, 정수로 정확히 나눠지지 않을 경우 1회를 더한다. 
        return int(np.ceil(len(self.labels) / self.batch_size))
    
    # batch_size 단위로 image_array, label_array 데이터를 가져와서 변환한 뒤 다시 반환함
    # 인자로 몇번째 batch 인지를 나타내는 index를 입력하면 해당 순서에 해당하는 batch_size 만큼의 데이타를 가공하여 반환
    # batch_size 갯수만큼 변환된 image_array와 label_array 반환. 
    def __getitem__(self, index):
        # index는 몇번째 batch인지를 나타냄. 
        # batch_size만큼 순차적으로 데이터를 가져오려면 array에서 index*self.batch_size:(index+1)*self.batch_size 만큼의 연속 데이터를 가져오면 됨
        # 32x32 image array를 self.batch_size만큼 가져옴. 
        images_fetch = self.images_array[index*self.batch_size:(index+1)*self.batch_size]
        if self.labels is not None:
            label_batch = self.labels[index*self.batch_size:(index+1)*self.batch_size]
        
        # 만일 객체 생성 인자로 albumentation으로 만든 augmentor가 주어진다면 아래와 같이 augmentor를 이용하여 image 변환
        # albumentations은 개별 image만 변환할 수 있으므로 batch_size만큼 할당된 image_name_batch를 한 건씩 iteration하면서 변환 수행. 
        # 변환된 image 배열값을 담을 image_batch 선언. image_batch 배열은 float32 로 설정. 
        image_batch = np.zeros((images_fetch.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3), dtype='float32')
        
        # batch_size에 담긴 건수만큼 iteration 하면서 opencv image load -> image augmentation 변환(augmentor가 not None일 경우)-> image_batch에 담음. 
        for image_index in range(images_fetch.shape[0]):
            #image = cv2.cvtColor(cv2.imread(image_name_batch[image_index]), cv2.COLOR_BGR2RGB)
            # 원본 image를 IMAGE_SIZE x IMAGE_SIZE 크기로 변환
            image = cv2.resize(images_fetch[image_index], (IMAGE_SIZE, IMAGE_SIZE))
            # 만약 augmentor가 주어졌다면 이를 적용. 
            if self.augmentor is not None:
                image = self.augmentor(image=image)['image']
                
            # 만약 scaling 함수가 입력되었다면 이를 적용하여 scaling 수행. 
            if self.pre_func is not None:
                image = self.pre_func(image)
            
            # image_batch에 순차적으로 변환된 image를 담음.               
            image_batch[image_index] = image
        
        return image_batch, label_batch
    
    # epoch가 한번 수행이 완료 될 때마다 모델의 fit()에서 호출됨. 
    def on_epoch_end(self):
        if(self.shuffle):
            #print('epoch end')
            # 원본 image배열과 label를 쌍을 맞춰서 섞어준다. scikt learn의 utils.shuffle에서 해당 기능 제공
            self.images_array, self.labels = sklearn.utils.shuffle(self.images_array, self.labels)
        else:
            pass

# %%
# CIFAR10 데이터 재 로딩 및 OHE 전처리 적용하여 학습/검증/데이터 세트 생성. 
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
print(train_images.shape, train_labels.shape, test_images.shape, test_labels.shape)

(tr_images, tr_oh_labels), (val_images, val_oh_labels), (test_images, test_oh_labels) = \
    get_train_valid_test_set(train_images, train_labels, test_images, test_labels, valid_size=0.2, random_state=2021)
print(tr_images.shape, tr_oh_labels.shape, val_images.shape, val_oh_labels.shape, test_images.shape, test_oh_labels.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)
# (40000, 32, 32, 3) (40000, 10) (10000, 32, 32, 3) (10000, 10) (10000, 32, 32, 3) (10000, 10)

# %% [markdown]
# # 원-hot encoding 학습 검증/테스트 데이터 세트 분할

# %%
from tensorflow.keras.applications.xception import preprocess_input as xception_preprocess

tr_ds = CIFAR_Dataset(tr_images, tr_oh_labels, batch_size=BATCH_SIZE, augmentor=None, shuffle=True, pre_func=xception_preprocess)
val_ds = CIFAR_Dataset(val_images, val_oh_labels, batch_size=BATCH_SIZE, augmentor=None, shuffle=False, pre_func=xception_preprocess)

print(next(iter(tr_ds))[0].shape, next(iter(val_ds))[0].shape)
print(next(iter(tr_ds))[1].shape, next(iter(val_ds))[1].shape)
# 채널별 값 - [103.939, 116.779, 123.68]
print(next(iter(tr_ds))[0][0])
# Out:
# (64, 128, 128, 3) (64, 128, 128, 3)
# (64, 10) (64, 10)
# [[[ 0.28627455  0.36470592  0.38823533]
#   [ 0.28627455  0.36470592  0.38823533]
#   [ 0.27058828  0.3411765   0.36470592]
#   ...
#   [-0.42745095 -0.41960782 -0.4588235 ]
#   [-0.45098037 -0.4352941  -0.46666664]
#   [-0.45098037 -0.4352941  -0.46666664]]
#
#  [[ 0.28627455  0.36470592  0.38823533]
#   [ 0.28627455  0.36470592  0.38823533]
#   [ 0.27058828  0.3411765   0.36470592]
#   ...
#   [-0.42745095 -0.41960782 -0.4588235 ]
#   [-0.45098037 -0.4352941  -0.46666664]
#   [-0.45098037 -0.4352941  -0.46666664]]
#
#  [[ 0.30196083  0.3803922   0.4039216 ]
#   [ 0.30196083  0.3803922   0.4039216 ]
#   [ 0.28627455  0.35686278  0.3803922 ]
#   ...
#   [-0.42745095 -0.41960782 -0.4588235 ]
#   [-0.44313723 -0.4352941  -0.46666664]
#   [-0.44313723 -0.4352941  -0.46666664]]
#
#  ...
#
#  [[ 0.827451    0.7176471   0.75686276]
#   [ 0.827451    0.7176471   0.75686276]
#   [ 0.8117647   0.69411767  0.7254902 ]
#   ...
#   [-0.46666664 -0.4352941  -0.46666664]
#   [-0.45098037 -0.42745095 -0.4588235 ]
#   [-0.45098037 -0.42745095 -0.4588235 ]]
#
#  [[ 0.8352941   0.7254902   0.7647059 ]
#   [ 0.8352941   0.7254902   0.7647059 ]
#   [ 0.8117647   0.7019608   0.73333335]
#   ...
#   [-0.47450978 -0.44313723 -0.47450978]
#   [-0.4588235  -0.4352941  -0.46666664]
#   [-0.4588235  -0.4352941  -0.46666664]]
#
#  [[ 0.8352941   0.7254902   0.7647059 ]
#   [ 0.8352941   0.7254902   0.7647059 ]
#   [ 0.8117647   0.7019608   0.73333335]
#   ...
#   [-0.46666664 -0.44313723 -0.47450978]
#   [-0.4588235  -0.4352941  -0.46666664]
#   [-0.4588235  -0.4352941  -0.46666664]]]

# %%
xception_model = create_Xception(in_shape=(128,128,3), n_classes=10)
xception_model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# 초기 learning_rate = 0.001

# %%
# 5번 iteration내에 validation loss가 향상되지 않으면 learning rate을 기존 learning rate * 0.2로 줄임.  
rlr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, mode='min', verbose=1)
ely_cb = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)

history = xception_model.fit(tr_ds, epochs=30, 
                    #steps_per_epoch=int(np.ceil(tr_images.shape[0]/BATCH_SIZE)),
                    validation_data=val_ds, 
                    #validation_steps=int(np.ceil(val_images.shape[0]/BATCH_SIZE)), 
                    callbacks=[rlr_cb, ely_cb]
                   )
# Out:
# Epoch 1/30
# 625/625 [==============================] - 274s 431ms/step - loss: 1.2395 - accuracy: 0.5556 - val_loss: 1.3091 - val_accuracy: 0.5821 - lr: 0.0010
# Epoch 2/30
# 625/625 [==============================] - 269s 430ms/step - loss: 0.7514 - accuracy: 0.7357 - val_loss: 1.0614 - val_accuracy: 0.6784 - lr: 0.0010
# Epoch 3/30
# 625/625 [==============================] - 269s 430ms/step - loss: 0.5567 - accuracy: 0.8055 - val_loss: 1.0086 - val_accuracy: 0.6901 - lr: 0.0010
# Epoch 4/30
# 625/625 [==============================] - 268s 429ms/step - loss: 0.4317 - accuracy: 0.8499 - val_loss: 0.7774 - val_accuracy: 0.7582 - lr: 0.0010
# Epoch 5/30
# 625/625 [==============================] - 268s 429ms/step - loss: 0.3342 - accuracy: 0.8835 - val_loss: 0.8781 - val_accuracy: 0.7581 - lr: 0.0010
# Epoch 6/30
# 625/625 [==============================] - 268s 429ms/step - loss: 0.2542 - accuracy: 0.9114 - val_loss: 0.8381 - val_accuracy: 0.7730 - lr: 0.0010
# Epoch 7/30
# 625/625 [==============================] - 268s 429ms/step - loss: 0.1916 - accuracy: 0.9337 - val_loss: 0.6632 - val_accuracy: 0.8138 - lr: 0.0010
# Epoch 8/30
# 625/625 [==============================] - 268s 428ms/step - loss: 0.1528 - accuracy: 0.9459 - val_loss: 0.8310 - val_accuracy: 0.7895 - lr: 0.0010
# Epoch 9/30
# 625/625 [==============================] - 269s 430ms/step - loss: 0.1146 - accuracy: 0.9608 - val_loss: 0.6219 - val_accuracy: 0.8334 - lr: 0.0010
# Epoch 10/30
# 625/625 [==============================] - 268s 429ms/step - loss: 0.0989 - accuracy: 0.9658 - val_loss: 1.1538 - val_accuracy: 0.7627 - lr: 0.0010
# Epoch 11/30
# 625/625 [==============================] - 268s 430ms/step - loss: 0.0816 - accuracy: 0.9715 - val_loss: 0.6903 - val_accuracy: 0.8354 - lr: 0.0010
# Epoch 12/30
# 625/625 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9735
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 625/625 [==============================] - 268s 429ms/step - loss: 0.0758 - accuracy: 0.9735 - val_loss: 1.4678 - val_accuracy: 0.7349 - lr: 0.0010
# Epoch 13/30
# 625/625 [==============================] - 268s 429ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 0.5609 - val_accuracy: 0.8776 - lr: 2.0000e-04
# Epoch 14/30
# 625/625 [==============================] - 268s 428ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.6399 - val_accuracy: 0.8778 - lr: 2.0000e-04
# Epoch 15/30
# 625/625 [==============================] - 268s 429ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.6943 - val_accuracy: 0.8793 - lr: 2.0000e-04
# Epoch 16/30
# 625/625 [==============================] - ETA: 0s - loss: 6.9720e-04 - accuracy: 0.9999
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 625/625 [==============================] - 268s 429ms/step - loss: 6.9720e-04 - accuracy: 0.9999 - val_loss: 0.8290 - val_accuracy: 0.8701 - lr: 2.0000e-04
# Epoch 17/30
# 625/625 [==============================] - 268s 430ms/step - loss: 6.2155e-04 - accuracy: 0.9999 - val_loss: 0.7801 - val_accuracy: 0.8788 - lr: 4.0000e-05
# Epoch 18/30
# 625/625 [==============================] - 269s 430ms/step - loss: 4.7382e-04 - accuracy: 0.9999 - val_loss: 0.7893 - val_accuracy: 0.8792 - lr: 4.0000e-05
# Epoch 19/30
# 625/625 [==============================] - ETA: 0s - loss: 3.6688e-04 - accuracy: 0.9999
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 625/625 [==============================] - 268s 430ms/step - loss: 3.6688e-04 - accuracy: 0.9999 - val_loss: 0.8080 - val_accuracy: 0.8788 - lr: 4.0000e-05
# Epoch 20/30
# 625/625 [==============================] - 268s 429ms/step - loss: 2.7241e-04 - accuracy: 0.9999 - val_loss: 0.8080 - val_accuracy: 0.8795 - lr: 8.0000e-06
# Epoch 21/30
# 625/625 [==============================] - 269s 430ms/step - loss: 1.9367e-04 - accuracy: 1.0000 - val_loss: 0.8104 - val_accuracy: 0.8798 - lr: 8.0000e-06
# Epoch 22/30
# 625/625 [==============================] - ETA: 0s - loss: 1.9303e-04 - accuracy: 1.0000
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 625/625 [==============================] - 268s 428ms/step - loss: 1.9303e-04 - accuracy: 1.0000 - val_loss: 0.8169 - val_accuracy: 0.8795 - lr: 8.0000e-06
# Epoch 23/30
# 625/625 [==============================] - 268s 429ms/step - loss: 1.8281e-04 - accuracy: 1.0000 - val_loss: 0.8175 - val_accuracy: 0.8794 - lr: 1.6000e-06
# Epoch 23: early stopping

# %%
test_ds = CIFAR_Dataset(test_images, test_oh_labels, batch_size=BATCH_SIZE, augmentor=None, shuffle=False, pre_func=xception_preprocess)
xception_model.evaluate(test_ds)
# Out:
# 157/157 [==============================] - 14s 90ms/step - loss: 0.8981 - accuracy: 0.8757
# [0.8980548977851868, 0.8756999969482422]

# %%
from tensorflow.keras.applications import Xception

input_tensor = Input(shape=(128, 128, 3))
base_model = Xception(include_top=False, weights=None, input_tensor=input_tensor)
bm_output = base_model.output

# classification dense layer와 연결 전 GlobalAveragePooling 수행 
x = GlobalAveragePooling2D(name='avg_pool')(bm_output)
x = Dropout(rate=0.5)(x)
x = Dense(200, activation='relu', name='fc_01')(x)
x = Dropout(rate=0.5)(x)
output = Dense(10, activation='softmax', name='fc_final')(x)

pr_model = Model(inputs=input_tensor, outputs=output, name='resnet50')
pr_model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 63, 63, 32)   864         ['input_12[0][0]']
#
#  block1_conv1_bn (BatchNormaliz  (None, 63, 63, 32)  128         ['block1_conv1[0][0]']
#  ation)
#
#  block1_conv1_act (Activation)  (None, 63, 63, 32)   0           ['block1_conv1_bn[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 61, 61, 64)   18432       ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNormaliz  (None, 61, 61, 64)  256         ['block1_conv2[0][0]']
#  ation)
#
#  block1_conv2_act (Activation)  (None, 61, 61, 64)   0           ['block1_conv2_bn[0][0]']
#
#  block2_sepconv1 (SeparableConv  (None, 61, 61, 128)  8768       ['block1_conv2_act[0][0]']
#  2D)
#
#  block2_sepconv1_bn (BatchNorma  (None, 61, 61, 128)  512        ['block2_sepconv1[0][0]']
#  lization)
#
#  block2_sepconv2_act (Activatio  (None, 61, 61, 128)  0          ['block2_sepconv1_bn[0][0]']
#  n)
#
#  block2_sepconv2 (SeparableConv  (None, 61, 61, 128)  17536      ['block2_sepconv2_act[0][0]']
#  2D)
#
#  block2_sepconv2_bn (BatchNorma  (None, 61, 61, 128)  512        ['block2_sepconv2[0][0]']
#  lization)
#
#  conv2d_66 (Conv2D)             (None, 31, 31, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 31, 31, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_440 (Batch  (None, 31, 31, 128)  512        ['conv2d_66[0][0]']
#  Normalization)
#
#  add_132 (Add)                  (None, 31, 31, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization_440[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 31, 31, 128)  0          ['add_132[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 31, 31, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 31, 31, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 31, 31, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 31, 31, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 31, 31, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_67 (Conv2D)             (None, 16, 16, 256)  32768       ['add_132[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 16, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_441 (Batch  (None, 16, 16, 256)  1024       ['conv2d_67[0][0]']
#  Normalization)
#
#  add_133 (Add)                  (None, 16, 16, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_441[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 16, 16, 256)  0          ['add_133[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 16, 16, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_68 (Conv2D)             (None, 8, 8, 728)    186368      ['add_133[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 8, 8, 728)    0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_442 (Batch  (None, 8, 8, 728)   2912        ['conv2d_68[0][0]']
#  Normalization)
#
#  add_134 (Add)                  (None, 8, 8, 728)    0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_442[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 8, 8, 728)   0           ['add_134[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 8, 8, 728)   536536      ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 8, 8, 728)   0           ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 8, 8, 728)   536536      ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 8, 8, 728)   0           ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 8, 8, 728)   536536      ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block5_sepconv3[0][0]']
#  lization)
#
#  add_135 (Add)                  (None, 8, 8, 728)    0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_134[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 8, 8, 728)   0           ['add_135[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 8, 8, 728)   536536      ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 8, 8, 728)   0           ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 8, 8, 728)   536536      ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 8, 8, 728)   0           ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 8, 8, 728)   536536      ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block6_sepconv3[0][0]']
#  lization)
#
#  add_136 (Add)                  (None, 8, 8, 728)    0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_135[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 8, 8, 728)   0           ['add_136[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 8, 8, 728)   536536      ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 8, 8, 728)   0           ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 8, 8, 728)   536536      ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 8, 8, 728)   0           ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 8, 8, 728)   536536      ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block7_sepconv3[0][0]']
#  lization)
#
#  add_137 (Add)                  (None, 8, 8, 728)    0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_136[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 8, 8, 728)   0           ['add_137[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 8, 8, 728)   536536      ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 8, 8, 728)   0           ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 8, 8, 728)   536536      ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 8, 8, 728)   0           ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 8, 8, 728)   536536      ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block8_sepconv3[0][0]']
#  lization)
#
#  add_138 (Add)                  (None, 8, 8, 728)    0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_137[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 8, 8, 728)   0           ['add_138[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 8, 8, 728)   536536      ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 8, 8, 728)   0           ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 8, 8, 728)   536536      ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 8, 8, 728)   0           ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 8, 8, 728)   536536      ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 8, 8, 728)   2912        ['block9_sepconv3[0][0]']
#  lization)
#
#  add_139 (Add)                  (None, 8, 8, 728)    0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_138[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 8, 8, 728)   0           ['add_139[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 8, 8, 728)   536536      ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 8, 8, 728)   2912        ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 8, 8, 728)   0           ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 8, 8, 728)   536536      ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 8, 8, 728)   2912        ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 8, 8, 728)   0           ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 8, 8, 728)   536536      ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 8, 8, 728)   2912        ['block10_sepconv3[0][0]']
#  alization)
#
#  add_140 (Add)                  (None, 8, 8, 728)    0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_139[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 8, 8, 728)   0           ['add_140[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 8, 8, 728)   536536      ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 8, 8, 728)   2912        ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 8, 8, 728)   0           ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 8, 8, 728)   536536      ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 8, 8, 728)   2912        ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 8, 8, 728)   0           ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 8, 8, 728)   536536      ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 8, 8, 728)   2912        ['block11_sepconv3[0][0]']
#  alization)
#
#  add_141 (Add)                  (None, 8, 8, 728)    0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_140[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 8, 8, 728)   0           ['add_141[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 8, 8, 728)   536536      ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 8, 8, 728)   2912        ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 8, 8, 728)   0           ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 8, 8, 728)   536536      ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 8, 8, 728)   2912        ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 8, 8, 728)   0           ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 8, 8, 728)   536536      ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 8, 8, 728)   2912        ['block12_sepconv3[0][0]']
#  alization)
#
#  add_142 (Add)                  (None, 8, 8, 728)    0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_141[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 8, 8, 728)   0           ['add_142[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 8, 8, 728)   536536      ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 8, 8, 728)   2912        ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 8, 8, 728)   0           ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 8, 8, 1024)  752024      ['block13_sepconv2_act[0][0]']
#  v2D)
#
#  block13_sepconv2_bn (BatchNorm  (None, 8, 8, 1024)  4096        ['block13_sepconv2[0][0]']
#  alization)
#
#  conv2d_69 (Conv2D)             (None, 4, 4, 1024)   745472      ['add_142[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 4, 4, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_443 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_69[0][0]']
#  Normalization)
#
#  add_143 (Add)                  (None, 4, 4, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_443[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 4, 4, 1536)  1582080     ['add_143[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 4, 4, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 4, 4, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 4, 4, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 4, 4, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 4, 4, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['block14_sepconv2_act[0][0]']
#  2D)
#
#  dropout (Dropout)              (None, 2048)         0           ['avg_pool[0][0]']
#
#  fc_01 (Dense)                  (None, 200)          409800      ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 200)          0           ['fc_01[0][0]']
#
#  fc_final (Dense)               (None, 10)           2010        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 21,273,290
# Trainable params: 21,218,762
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
pr_model.compile(optimizer=Adam(lr=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

history = pr_model.fit(tr_ds, epochs=30, 
                    validation_data=val_ds,
                    callbacks=[rlr_cb, ely_cb]
                   )

test_ds = CIFAR_Dataset(test_images, test_oh_labels, batch_size=BATCH_SIZE, augmentor=None, shuffle=False, pre_func=xception_preprocess)
pr_model.evaluate(test_ds)
# Out:
# Epoch 1/30
# 625/625 [==============================] - 267s 419ms/step - loss: 1.4888 - accuracy: 0.4578 - val_loss: 2.4315 - val_accuracy: 0.1302 - lr: 1.0000e-04
# Epoch 2/30
# 625/625 [==============================] - 261s 418ms/step - loss: 0.9930 - accuracy: 0.6549 - val_loss: 1.2002 - val_accuracy: 0.6007 - lr: 1.0000e-04
# Epoch 3/30
# 625/625 [==============================] - 261s 418ms/step - loss: 0.7149 - accuracy: 0.7584 - val_loss: 0.9812 - val_accuracy: 0.6660 - lr: 1.0000e-04
# Epoch 4/30
# 625/625 [==============================] - 261s 418ms/step - loss: 0.4868 - accuracy: 0.8363 - val_loss: 1.0346 - val_accuracy: 0.6784 - lr: 1.0000e-04
# Epoch 5/30
# 625/625 [==============================] - 261s 418ms/step - loss: 0.3145 - accuracy: 0.8942 - val_loss: 1.1156 - val_accuracy: 0.6879 - lr: 1.0000e-04
# Epoch 6/30
# 625/625 [==============================] - ETA: 0s - loss: 0.2104 - accuracy: 0.9310
# Epoch 6: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 625/625 [==============================] - 261s 418ms/step - loss: 0.2104 - accuracy: 0.9310 - val_loss: 1.4422 - val_accuracy: 0.6586 - lr: 1.0000e-04
# Epoch 7/30
# 625/625 [==============================] - 261s 418ms/step - loss: 0.0601 - accuracy: 0.9812 - val_loss: 0.9394 - val_accuracy: 0.7709 - lr: 2.0000e-05
# Epoch 8/30
# 625/625 [==============================] - 261s 418ms/step - loss: 0.0209 - accuracy: 0.9945 - val_loss: 1.0204 - val_accuracy: 0.7731 - lr: 2.0000e-05
# Epoch 9/30
# 625/625 [==============================] - 261s 418ms/step - loss: 0.0110 - accuracy: 0.9970 - val_loss: 1.0341 - val_accuracy: 0.7808 - lr: 2.0000e-05
# Epoch 10/30
# 625/625 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9967
# Epoch 10: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 625/625 [==============================] - 261s 418ms/step - loss: 0.0106 - accuracy: 0.9967 - val_loss: 1.1682 - val_accuracy: 0.7703 - lr: 2.0000e-05
# Epoch 11/30
# 625/625 [==============================] - 261s 418ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 1.0870 - val_accuracy: 0.7820 - lr: 4.0000e-06
# Epoch 12/30
# 625/625 [==============================] - 261s 417ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 1.0988 - val_accuracy: 0.7798 - lr: 4.0000e-06
# Epoch 13/30
# 625/625 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9992
# Epoch 13: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 625/625 [==============================] - 261s 418ms/step - loss: 0.0038 - accuracy: 0.9992 - val_loss: 1.1082 - val_accuracy: 0.7823 - lr: 4.0000e-06
# Epoch 14/30
# 625/625 [==============================] - 261s 418ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 1.0979 - val_accuracy: 0.7839 - lr: 8.0000e-07
# Epoch 15/30
# 625/625 [==============================] - 261s 418ms/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 1.1001 - val_accuracy: 0.7849 - lr: 8.0000e-07
# Epoch 16/30
# 625/625 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9992
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 625/625 [==============================] - 261s 418ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 1.0996 - val_accuracy: 0.7831 - lr: 8.0000e-07
# Epoch 17/30
# 625/625 [==============================] - 261s 418ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 1.0981 - val_accuracy: 0.7846 - lr: 1.6000e-07
# Epoch 17: early stopping
# 157/157 [==============================] - 14s 87ms/step - loss: 1.1664 - accuracy: 0.7780
# [1.1664042472839355, 0.777999997138977]
